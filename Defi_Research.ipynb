# %% [markdown]
# <a href="https://colab.research.google.com/github/luismael15/DeFi_Research/blob/main/Defi_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
file_path = '/content/chain-dataset-All.csv'
df = pd.read_csv(file_path, header=None, sep=',', on_bad_lines='warn', engine='python') # Changed code
df = df.T

# %%
df.columns = df.iloc[0]  # Take the first row as column names
df = df[1:]  # Drop the old header row

# %%
# Rename the "Protocol" column to "Date"
df.rename(columns={"Protocol": "Date"}, inplace=True)
# Out:
# 0           Date               Total          TokenStore             Hats.V1  \
# 1     27/04/2018  404077.85880970507  404077.85880970507                 NaN
# 2     28/04/2018   400585.0992127101   400585.0992127101                 NaN
# 3     29/04/2018   429213.9332003989   429213.9332003989                 NaN
# 4     30/04/2018  421651.15615802025  421651.15615802025                 NaN
# 5     01/05/2018    436194.969783108    436194.969783108                 NaN
# ...          ...                 ...                 ...                 ...
# 2515  15/03/2025   89572406513.98163   1224595.246108612   101519.9189843499
# 2516  16/03/2025   90755859306.23598  1244164.8909636466   102232.9669365384
# 2517  17/03/2025   88981331809.31812  1217417.1768818127  100195.14422071858
# 2518  18/03/2025   90232613468.43912  1234078.4574828637   98117.71514366742
# 2519  19/03/2025   90201970146.46175  1242324.3000256934   94578.72201012043
#
# 0            Compound V1          Uniswap V1            MakerDAO  \
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# 5                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2515  2518607.0243638223   5034863.732319012   2460151350.948953
# 2516  2550121.5752594112   5103686.252076899  2489876478.1159816
# 2517  2477621.7237854423  5013010.0266171405  2438842945.3332877
# 2518  2530330.1514863544   5079919.587398361  2470977671.0757527
# 2519   2544568.316740206   5120474.464011563  2438104479.4425178
#
# 0                PoWH3D              Fomo3D         Compound V2  ...  \
# 1                   NaN                 NaN                 NaN  ...
# 2                   NaN                 NaN                 NaN  ...
# 3                   NaN                 NaN                 NaN  ...
# 4                   NaN                 NaN                 NaN  ...
# 5                   NaN                 NaN                 NaN  ...
# ...                 ...                 ...                 ...  ...
# 2515  4282469.256656517  2302282.5773512716   466036802.9346137  ...
# 2516  4345772.770424612  2336314.9470190424   470257040.5508697  ...
# 2517  4257026.803353831  2288604.5534231835  462465699.18258107  ...
# 2518  4315174.577686138  2322094.6225827923  446740456.25164616  ...
# 2519  4340863.609831406   2335531.624062808   445961662.2005285  ...
#
# 0        Bitbond Lockers       Bitbond Sales              Stout  \
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
# 5                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 2515   327858.6770328366  3874.3071820431346  675626.9040387212
# 2516   413044.5783430922   8372.010492869944  672795.8467980818
# 2517   406967.3888618847   8293.304986710875  674170.4854805185
# 2518  413702.65648516896   8364.085915142208  655654.4352768343
# 2519    411222.829932212   8363.975302485436  642552.4144660693
#
# 0       GoPlus Locker V2        Yuzu Finance    GoPlus Locker V3  \
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# 5                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 2515  3110.5002188627323  22439.553140928452  15163257.279194253
# 2516  3269.2926550054385  22098.743393386743   17690981.29056956
# 2517   3212.338524478821   19644.68539042872  18564446.247495078
# 2518   3334.031571981556   23382.85630563045  23139752.707451373
# 2519  3267.6480500234625   38997.28670570123   23187830.89285398
#
# 0       RFX Exchange V2               CLAMM     Chedda Finance  \
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4                   NaN                 NaN                NaN
# 5                   NaN                 NaN                NaN
# ...                 ...                 ...                ...
# 2515                NaN                 NaN                NaN
# 2516                NaN                 NaN                NaN
# 2517  617622.0329662268  1068.6682979142176   4543.02584881754
# 2518  590171.1351226429  1082.1352361735114  4581.090078568921
# 2519   587914.452506257  1092.5896484180416  4535.747611373879
#
# 0              Ekubo EVM
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# ...                  ...
# 2515                 NaN
# 2516                 NaN
# 2517                 NaN
# 2518  2715809.2740658876
# 2519  2481338.3561233957
#
# [2519 rows x 3493 columns]

# %%
# Ensure 'Date' is in datetime format
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# Convert all other columns to numeric (Total, Token Store, Protocols)
df.iloc[:, 1:] = df.iloc[:, 1:].apply(pd.to_numeric, errors="coerce")

# Set 'Date' as the index
df.set_index("Date", inplace=True)
# Out:
# <ipython-input-53-4a6f0af3510e>:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2519 entries, 2018-04-27 to 2025-03-19
# Columns: 3492 entries, Total to Ekubo EVM
# dtypes: object(3492)
# memory usage: 67.1+ MB
# None
#
# First 5 Rows:
#  0                   Total     TokenStore Hats.V1 Compound V1 Uniswap V1  \
# Date
# 2018-04-27   404077.85881   404077.85881     NaN         NaN        NaN
# 2018-04-28  400585.099213  400585.099213     NaN         NaN        NaN
# 2018-04-29    429213.9332    429213.9332     NaN         NaN        NaN
# 2018-04-30  421651.156158  421651.156158     NaN         NaN        NaN
# 2018-05-01  436194.969783  436194.969783     NaN         NaN        NaN
#
# 0          MakerDAO PoWH3D Fomo3D Compound V2 Nexus Mutual  ...  \
# Date                                                        ...
# 2018-04-27      NaN    NaN    NaN         NaN          NaN  ...
# 2018-04-28      NaN    NaN    NaN         NaN          NaN  ...
# 2018-04-29      NaN    NaN    NaN         NaN          NaN  ...
# 2018-04-30      NaN    NaN    NaN         NaN          NaN  ...
# 2018-05-01      NaN    NaN    NaN         NaN          NaN  ...
#
# 0          Bitbond Lockers Bitbond Sales Stout GoPlus Locker V2 Yuzu Finance  \
# Date
# 2018-04-27             NaN           NaN   NaN              NaN          NaN
# 2018-04-28             NaN           NaN   NaN              NaN          NaN
# 2018-04-29             NaN           NaN   NaN              NaN          NaN
# 2018-04-30             NaN           NaN   NaN              NaN          NaN
# 2018-05-01             NaN           NaN   NaN              NaN          NaN
#
# 0          GoPlus Locker V3 RFX Exchange V2 CLAMM Chedda Finance Ekubo EVM
# Date
# 2018-04-27              NaN             NaN   NaN            NaN       NaN
# 2018-04-28              NaN             NaN   NaN            NaN       NaN
# 2018-04-29              NaN             NaN   NaN            NaN       NaN
# 2018-04-30              NaN             NaN   NaN            NaN       NaN
# 2018-05-01              NaN             NaN   NaN            NaN       NaN
#
# [5 rows x 3492 columns]

# %%
# Replace NaN values with zeros
df = df.fillna(0)
df
# Out:
# 0                  Total    TokenStore        Hats.V1   Compound V1  \
# Date
# 2018-04-27  4.040779e+05  4.040779e+05       0.000000  0.000000e+00
# 2018-04-28  4.005851e+05  4.005851e+05       0.000000  0.000000e+00
# 2018-04-29  4.292139e+05  4.292139e+05       0.000000  0.000000e+00
# 2018-04-30  4.216512e+05  4.216512e+05       0.000000  0.000000e+00
# 2018-05-01  4.361950e+05  4.361950e+05       0.000000  0.000000e+00
# ...                  ...           ...            ...           ...
# 2025-03-15  8.957241e+10  1.224595e+06  101519.918984  2.518607e+06
# 2025-03-16  9.075586e+10  1.244165e+06  102232.966937  2.550122e+06
# 2025-03-17  8.898133e+10  1.217417e+06  100195.144221  2.477622e+06
# 2025-03-18  9.023261e+10  1.234078e+06   98117.715144  2.530330e+06
# 2025-03-19  9.020197e+10  1.242324e+06   94578.722010  2.544568e+06
#
# 0             Uniswap V1      MakerDAO        PoWH3D        Fomo3D  \
# Date
# 2018-04-27  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2018-04-28  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2018-04-29  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2018-04-30  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2018-05-01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...                  ...           ...           ...           ...
# 2025-03-15  5.034864e+06  2.460151e+09  4.282469e+06  2.302283e+06
# 2025-03-16  5.103686e+06  2.489876e+09  4.345773e+06  2.336315e+06
# 2025-03-17  5.013010e+06  2.438843e+09  4.257027e+06  2.288605e+06
# 2025-03-18  5.079920e+06  2.470978e+09  4.315175e+06  2.322095e+06
# 2025-03-19  5.120474e+06  2.438104e+09  4.340864e+06  2.335532e+06
#
# 0            Compound V2  Nexus Mutual  ...  Bitbond Lockers  Bitbond Sales  \
# Date                                    ...
# 2018-04-27  0.000000e+00  0.000000e+00  ...         0.000000       0.000000
# 2018-04-28  0.000000e+00  0.000000e+00  ...         0.000000       0.000000
# 2018-04-29  0.000000e+00  0.000000e+00  ...         0.000000       0.000000
# 2018-04-30  0.000000e+00  0.000000e+00  ...         0.000000       0.000000
# 2018-05-01  0.000000e+00  0.000000e+00  ...         0.000000       0.000000
# ...                  ...           ...  ...              ...            ...
# 2025-03-15  4.660368e+08  1.344850e+08  ...    327858.677033    3874.307182
# 2025-03-16  4.702570e+08  1.363382e+08  ...    413044.578343    8372.010493
# 2025-03-17  4.624657e+08  1.334440e+08  ...    406967.388862    8293.304987
# 2025-03-18  4.467405e+08  1.350924e+08  ...    413702.656485    8364.085915
# 2025-03-19  4.459617e+08  1.357216e+08  ...    411222.829932    8363.975302
#
# 0                   Stout  GoPlus Locker V2  Yuzu Finance  GoPlus Locker V3  \
# Date
# 2018-04-27       0.000000          0.000000      0.000000      0.000000e+00
# 2018-04-28       0.000000          0.000000      0.000000      0.000000e+00
# 2018-04-29       0.000000          0.000000      0.000000      0.000000e+00
# 2018-04-30       0.000000          0.000000      0.000000      0.000000e+00
# 2018-05-01       0.000000          0.000000      0.000000      0.000000e+00
# ...                   ...               ...           ...               ...
# 2025-03-15  675626.904039       3110.500219  22439.553141      1.516326e+07
# 2025-03-16  672795.846798       3269.292655  22098.743393      1.769098e+07
# 2025-03-17  674170.485481       3212.338524  19644.685390      1.856445e+07
# 2025-03-18  655654.435277       3334.031572  23382.856306      2.313975e+07
# 2025-03-19  642552.414466       3267.648050  38997.286706      2.318783e+07
#
# 0           RFX Exchange V2        CLAMM  Chedda Finance     Ekubo EVM
# Date
# 2018-04-27         0.000000     0.000000        0.000000  0.000000e+00
# 2018-04-28         0.000000     0.000000        0.000000  0.000000e+00
# 2018-04-29         0.000000     0.000000        0.000000  0.000000e+00
# 2018-04-30         0.000000     0.000000        0.000000  0.000000e+00
# 2018-05-01         0.000000     0.000000        0.000000  0.000000e+00
# ...                     ...          ...             ...           ...
# 2025-03-15         0.000000     0.000000        0.000000  0.000000e+00
# 2025-03-16         0.000000     0.000000        0.000000  0.000000e+00
# 2025-03-17    617622.032966  1068.668298     4543.025849  0.000000e+00
# 2025-03-18    590171.135123  1082.135236     4581.090079  2.715809e+06
# 2025-03-19    587914.452506  1092.589648     4535.747611  2.481338e+06
#
# [2519 rows x 3492 columns]
